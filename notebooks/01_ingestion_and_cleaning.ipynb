# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import sys
os.chdir('..')
sys.path.insert(0, os.getcwd())
os.getcwd()
# Out:
# 'c:\\Users\\Jan Brix Ilan\\OneDrive\\Github repositories\\Supply-Chain-Performance-Analysis'

# %% [markdown]
# ## Data Loading
# Importing the CSV file

# %%
df = pd.read_csv(r'data\raw\DataCoSupplyChainDataset.csv',
            encoding='latin1',
            low_memory=False)

# %% [markdown]
# ## Data Cleaning
#
# Column names reformatting. Converting data types.

# %%
from scripts.cleaning import clean_column_names, convert_dates

df = clean_column_names(df)
df = convert_dates(df)

# %%
server = r'LAPTOP-OCKRNGU5\SQLEXPRESS'
database = 'SupplyChainDB'

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes"
    "&TrustServerCertificate=yes"
)

engine = create_engine(connection_string)

with engine.connect() as conn:
    print("Connection to the database established successfully.")

df.to_sql('supply_chain_data', con=engine, if_exists='replace', index=False)
# Out:
# Connection to the database established successfully.
# 27
